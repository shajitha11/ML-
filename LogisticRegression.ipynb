# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\shajitha Banu\Downloads\insurance_data (1).csv")
df
# Out:
#     age  affordibility  bought_insurance
# 0    22              1                 0
# 1    25              0                 0
# 2    47              1                 1
# 3    52              0                 0
# 4    46              1                 1
# 5    56              1                 1
# 6    55              0                 0
# 7    60              0                 1
# 8    62              1                 1
# 9    61              1                 1
# 10   18              1                 0
# 11   28              1                 0
# 12   27              0                 0
# 13   29              0                 0
# 14   49              1                 1
# 15   55              1                 1
# 16   25              0                 1
# 17   58              1                 1
# 18   19              0                 0
# 19   18              1                 0
# 20   21              1                 0
# 21   26              0                 0
# 22   40              1                 1
# 23   45              1                 1
# 24   50              1                 1
# 25   54              1                 1
# 26   23              1                 0
# 27   46              1                 0

# %%
plt.scatter(df.age,df.bought_insurance,marker='+',color='violet')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df[['age']],df.bought_insurance,test_size=0.2)

# %%
X_test
# Out:
#     age
# 14   49
# 0    22
# 13   29
# 21   26
# 27   46
# 5    56

# %%
X_train
# Out:
#     age
# 23   45
# 11   28
# 1    25
# 24   50
# 18   19
# 8    62
# 25   54
# 10   18
# 7    60
# 20   21
# 4    46
# 3    52
# 12   27
# 26   23
# 6    55
# 22   40
# 19   18
# 2    47
# 16   25
# 17   58
# 15   55
# 9    61

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 0.8333333333333334
